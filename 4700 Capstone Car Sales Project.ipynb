# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('car_sales.csv')

# %%
df.head(5)
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
df.Manufacturer.value_counts()
# Out:
# Dodge            11
# Ford             11
# Chevrolet         9
# Toyota            9
# Mercedes-Benz     9
# Chrysler          7
# Mitsubishi        7
# Nissan            7
# Mercury           6
# Pontiac           6
# Volvo             6
# Lexus             6
# Volkswagen        6
# Oldsmobile        6
# Honda             5
# Saturn            5
# Cadillac          5
# Plymouth          4
# Acura             4
# Buick             4
# Porsche           3
# Audi              3
# Lincoln           3
# Hyundai           3
# Jeep              3
# BMW               3
# Saab              2
# Subaru            2
# Infiniti          1
# Jaguar            1
# Name: Manufacturer, dtype: int64

# %%
df.describe(include=['object', 'category'])
# Out:
#          Manufacturer              Model 4-year resale value Vehicle type  \
# count             157                157                 157          157
# unique             30                156                 118            2
# top     Dodge          Neon                                .    Passenger
# freq               11                  2                  36          116
#
#        Price in thousands Engine size Horsepower Wheelbase Width Length  \
# count                 157         157        157       157   157    157
# unique                153          32         67        89    79    128
# top                  38.9           2        150     112.2  66.7  186.3
# freq                    2          17          9         8     6      4
#
#        Curb weight Fuel capacity Fuel efficiency Latest Launch
# count          157           157             157           157
# unique         148            56              21           130
# ...

# %%
df.describe(include=['number']).loc[["mean","min","max"]]
# Out:
#       Sales in thousands
# mean           52.998076
# min             0.110000
# max           540.561000

# %%
#overtime = np.array([5, 6, 7])
#df.loc[df['period'].isin(overtime), 'period'] = 'overtime'
#df['period'].value_counts()

plt.figure(figsize=(15,5))
plt.title('Shot Distance Variation Based On Minutes Remaining Per Period.', fontsize=15)
plt.legend(loc='bottom left')
shot_dist_per_min = sns.pointplot(x="Engine size", y="Price in thousands",  data=df)
#plt.xlabel("Minutes Remaining", fontsize=15)
#plt.ylabel("Shot Distance",fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-1d998430eb97> in <module>
#       6 plt.title('Shot Distance Variation Based On Minutes Remaining Per Period.', fontsize=15)
#       7 plt.legend(loc='bottom left')
# ----> 8 shot_dist_per_min = sns.pointplot(x="Engine size", y="Price in thousands",  data=df)
#       9 #plt.xlabel("Minutes Remaining", fontsize=15)
#      10 #plt.ylabel("Shot Distance",fontsize=15)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3122                             estimator, ci, n_boot, units,
#    3123                             markers, linestyles, dodge, join, scale,
# ...
